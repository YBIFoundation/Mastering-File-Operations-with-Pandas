# %% [markdown]
# # Pandas Day 1 — Reading CSV Files (Solution Notebook)
#
# Tasks:
# 1. Read the CSV file.
# 2. Show first 5 rows.
# 3. Display column data types.
# 4. Calculate mean score.
# 5. Read only selected columns (name, score).

# %%
# Import pandas
import pandas as pd

# %%
# Load CSV
df = pd.read_csv('/mnt/data/students_scores.csv')
df.head()

# %%
# Display dtypes
print(df.dtypes)

# %%
# Calculate mean score
print('Mean Score:', df['score'].mean())

# %%
# Read selected columns
subset = pd.read_csv('/mnt/data/students_scores.csv', usecols=['name','score'])
subset.head()
